# %% [markdown]
# LEVEL-2: ---
# We are now going to Level-2 of our trading system
#
# In this notebook, I will be:
# 1. Optimizing the trading strategy logic by incorporating additional indicators such as RSI (Relative Strength Index)
#    or MACD (Moving Average Convergence/Divergence)
#
# 2. Add logic to avoid market conditions such as volatility filters, in order to avoid false signals.
#
# 3. I'll also implement try-except blocks to manage API errors (e.g., Alpaca outages) and add logging to track trades and performance.

# %%
import asyncio
import platform
import alpaca_trade_api as tradeapi
import pandas as pd
import logging
import numpy as np
FPS = 60

# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Replace with your Alpaca API keys
API_KEY = 'PKMSXCZ5JFNRILSSDE7Z'
SECRET_KEY = '0xfaUPAQEifIEaSZbqOuUUEGlP4GJsa0GEAj5vHC'
BASE_URL = 'https://paper-api.alpaca.markets'

async def main():
    api = tradeapi.REST(API_KEY, SECRET_KEY, BASE_URL, api_version='v2')
    symbol = 'AAPL'

    def calculate_indicators(data):
        try:
            if len(data) < 50:  
                logger.warning(f"Insufficient data: {len(data)} bars")
                return None
            
            # Moving Averages
            data['short_mavg'] = data['close'].rolling(window=20, min_periods=1).mean()
            data['long_mavg'] = data['close'].rolling(window=50, min_periods=1).mean()
            
            # RSI
            delta = data['close'].diff()
            gain = (delta.where(delta > 0, 0)).rolling(window=14, min_periods=1).mean()
            loss = (-delta.where(delta < 0, 0)).rolling(window=14, min_periods=1).mean()
            rs = gain / loss.replace(0, 1e-10)  
            data['rsi'] = 100 - (100 / (1 + rs))
            
            # MACD
            exp1 = data['close'].ewm(span=12, adjust=False).mean()
            exp2 = data['close'].ewm(span=26, adjust=False).mean()
            macd = exp1 - exp2
            data['macd'] = macd
            data['signal'] = macd.ewm(span=9, adjust=False).mean()
            
            return data
        except Exception as e:
            logger.error(f"Error calculating indicators: {str(e)}")
            return None

    def update_loop():
        try:
            # Fetch data
            barset = api.get_bars(symbol, '1D', limit=200).df  
            if barset.empty:
                logger.warning("No data received")
                return

            # Calculate indicators
            data = calculate_indicators(barset)
            if data is None or len(data) < 50:
                return

            latest = data.iloc[-1]
            volatility = data['close'].pct_change().rolling(window=20, min_periods=1).std() * np.sqrt(252)
            current_vol = volatility.iloc[-1] if not np.isnan(volatility.iloc[-1]) else 0.0

            # Trading logic with filters
            if (latest['short_mavg'] > latest['long_mavg'] and 
                latest['rsi'] < 70 and 
                latest['macd'] > latest['signal'] and 
                current_vol < 0.3):
                logger.info("Buy signal triggered")
                api.submit_order(symbol, 10, 'buy', 'market', 'day')
            elif (latest['short_mavg'] < latest['long_mavg'] and 
                  latest['rsi'] > 30 and 
                  latest['macd'] < latest['signal'] and 
                  current_vol < 0.3):
                logger.info("Sell signal triggered")
                api.submit_order(symbol, 10, 'sell', 'market', 'day')
            else:
                logger.info("No action: Conditions not met")
        except Exception as e:
            logger.error(f"Error in update_loop: {e}")

    def setup():
        logger.info(f"Starting trading strategy for {symbol}")

    setup()
    while True:
        update_loop()
        asyncio.sleep(1.0 / FPS)  

if platform.system() == "Emscripten":
    asyncio.ensure_future(main())
else:
    loop = asyncio.get_event_loop()
    if loop.is_running():
        asyncio.ensure_future(main())
    else:
        loop.run_until_complete(main())
# Out:
# 2025-07-19 00:39:28,931 - INFO - Starting trading strategy for AAPL
# 2025-07-19 00:39:29,581 - WARNING - Insufficient data: 1 bars
# C:\Users\SOMEN\AppData\Local\Temp\ipykernel_19408\3064167156.py:92: RuntimeWarning: coroutine 'sleep' was never awaited
#   asyncio.sleep(1.0 / FPS)  # Non-async sleep for simplicity
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# 2025-07-19 00:39:29,820 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:30,029 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:30,237 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:30,444 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:30,644 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:30,845 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:31,049 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:31,259 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:31,463 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:31,670 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:31,871 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:32,082 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:32,284 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:32,486 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:32,688 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:32,889 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:33,094 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:33,299 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:33,504 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:33,710 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:33,917 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:34,123 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:34,328 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:34,531 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:34,737 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:34,942 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:35,145 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:35,351 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:35,553 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:35,755 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:35,960 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:36,162 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:36,363 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:36,568 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:36,772 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:36,976 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:37,177 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:37,381 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:37,583 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:37,789 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:38,069 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:38,308 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:38,633 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:38,914 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:39,193 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:39,475 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:39,715 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:39,981 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:40,250 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:40,516 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:40,783 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:41,051 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:41,317 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:41,582 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:41,847 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:42,113 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:42,379 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:42,643 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:42,910 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:43,172 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:43,441 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:43,703 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:44,374 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:45,265 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:45,469 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:45,677 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:45,882 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:46,088 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:46,294 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:46,500 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:46,702 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:46,915 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:47,123 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:47,330 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:47,534 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:47,740 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:47,945 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:48,153 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:48,356 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:48,560 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:48,764 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:48,969 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:49,172 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:49,376 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:49,581 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:49,784 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:49,990 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:50,193 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:50,395 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:50,597 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:50,797 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:51,000 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:51,202 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:51,405 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:51,611 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:51,817 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:52,023 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:52,229 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:52,434 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:52,637 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:52,838 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:53,042 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:53,247 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:53,463 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:53,668 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:53,871 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:54,073 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:54,274 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:54,481 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:54,684 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:54,887 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:55,087 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:55,290 - WARNING - Insufficient data: 1 bars
# 2025-07-19 00:39:55,503 - WARNING - Insufficient data: 1 bars
